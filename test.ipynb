# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/cm/archive/phucpht/Drug_research/Blind_pocket/datasets/dude_process/aa2ar/preprocessed_data/preprocessed_data.csv')

# %%
aa = df.sort_values(by = ['gnns_score', 'gnns_ba'], ascending=[False, True])
aa['index'] = range(len(df))

# %%
aa[aa['active'] == 1]
# Out:
#                                                   smiles  active  key_idx  \
# 29088  CCOC(=O)[C@H]1C(=c2cc(c(cc2=[NH+]1)OC)OC)NC(=O...       1     7618
# 10     C[C@@H]1C(=C(N=N1)C)[C@H](C)NC(=O)[C@@H]2CN(CC...       1    29562
# 13925  C[C@@H]1C(=O)[C@]2([C@]3([C@H](CC(=C)[C@@]2(C(...       1    10746
# 728    COc1ccc(cc1OC)[C@H]2C(=C(NC(=O)N2)C[NH+]3CCSCC...       1    20762
# 47     CC[C@@]1(C(=O)N(C(=O)N1)CC(=C)C)C2CCN(CC2)C(=O...       1     2696
# ...                                                  ...     ...      ...
# 19574  c1ccc2=[NH+]C([NH+]=c2c1)c3ccc(cc3)N4C(=O)c5cc...       1    28461
# 2491   CCc1c(sc2c1c(nc(n2)SCC(=O)N)N3CC[NH+](CC3)CC(=...       1     4194
# 7785   CCc1c(sc2c1c(nc(n2)SCC(=O)N(C)C)N3CC[NH+](CC3)...       1    14291
# 26013  [H]/N=c\1/c(=C/c2ccc(o2)c3ccc(cc3)Cl)/c(=O)nc-...       1    24182
# 2501   CN(C)S(=O)(=O)c1ccc(c(c1)NC(=O)CN2C(=O)C3(CCCC...       1    11702
#
#        gnns_score  gnns_ba      x      y      z  index
# ...
